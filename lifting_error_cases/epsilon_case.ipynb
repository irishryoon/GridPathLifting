# %%
import os, sys
import numpy as np 
import matplotlib.pyplot as plt
from copy import deepcopy
import pickle

sys.path.append('.')
from trajectory import World
from toroidal_coordinates.epsilon import compute_epsilon
from toroidal_coordinates.toroidal_lifting import toroidal_lifting_distance
from constants import GRID_FIELDS_PATH, TRAJ_PATH

# %%
num_holes = 2

traj = pickle.load(open(os.path.join(TRAJ_PATH, f"random_walk_{num_holes}holes.pkl"), "rb"))[0]

with np.load(os.path.join(GRID_FIELDS_PATH, f"world_{num_holes}holes", "toroidal_coords_dreimac.npz")) as data:
    cir_coords = data["coords"]

# %%
compute_epsilon(cir_coords)
# Out:
# 0.24084070449666733
# 0.24084070449666733

# %%
lifted_path = toroidal_lifting_distance(deepcopy(cir_coords), epsilon=0.01)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(traj[:, 0], traj[:, 1])
plt.subplot(1, 2, 2)
plt.plot(lifted_path[:, 0], lifted_path[:, 1])

# %%
lifted_path = toroidal_lifting_distance(deepcopy(cir_coords), epsilon=3)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(traj[:, 0], traj[:, 1])
plt.subplot(1, 2, 2)
plt.plot(lifted_path[:, 0], lifted_path[:, 1])
